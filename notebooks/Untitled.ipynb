# %%
import pandas as pd

# %%
city_2018 =  pd.read_csv('/Users/utilisateur/Documents/Le_Wagon/Resilience/cdp-unlocking-climate-solutions/Cities/Cities Responses/2018_Full_Cities_Dataset.csv')

# %%
city_2018
# Out:
#           Questionnaire  Year Reported to CDP  Account Number  \
# 0       CDP Cities 2018                  2018            3203
# 1       CDP Cities 2018                  2018           50555
# 2       CDP Cities 2018                  2018           50392
# 3       CDP Cities 2018                  2018           36522
# 4       CDP Cities 2018                  2018           35873
# ...                 ...                   ...             ...
# 186829  CDP Cities 2018                  2018           74594
# 186830  CDP Cities 2018                  2018           60602
# 186831  CDP Cities 2018                  2018           49334
# 186832  CDP Cities 2018                  2018           31108
# 186833  CDP Cities 2018                  2018           35858
#
#                     Organization                   Country     CDP Region  \
# 0                City of Chicago  United States of America  North America
# ...

# %%
city_2018['Question Name'].nunique()
# Out:
# 167

# %%
city_2018['Question Number'].unique()
# Out:
# array(['16.1', '2.2a', '8.4', '9.0', '7.13a', '7.11', '11.4', '1.2',
#        '7.3a', '2.0c', '9.3', '6.5', '9.2a', '0.5', '2.4',
#        'Response Language', '5.1a', '8.0b', '15.3a', '2.0b', '0.8', '6.6',
#        '5.2', '2.0', '3.3', '10.9', '0.6', '0.3', '4.0a', '7.13', '7.0',
#        '14.0', '7.2', '8.2b', '8.0a', '2.3', '3.1a', '0.1', '3.4', '6.1',
#        '15.4', '5.1', '11.0', '15.3', '7.10', '7.5', '8.1', '8.2c', '3.6',
#        '14.1', '7.7', '2.2', '1.4', '8.3', '1.4a', '6.8b', '5.5', '3.1',
#        '3.9', '0.4', '3.7', '14.6', '6.8a', '6.0', '0.7', '8.3a', '7.8',
#        '9.1', '9.2b', '1.3', '2.1a', '5.3', '7.12b', '3.8', '7.6a',
#        '2.0a', '14.3', '6.9', '6.7', '6.10a', '1.1', '7.1', '8.3b',
#        '9.3a', '5.4', '11.2', '10.7', '5.0', '3.2a', '3.0a', '5.8',
#        '8.2a', '13.1', '9.2', '14.4', '15.0', '6.4', '7.4a', '11.5',
#        '5.0a', '6.8', '15.3b', '14.5', '4.0', '10.8', '15.2', '0.2',
# ...

# %%
city_2018['Section'].nunique()
# Out:
# 37

# %%
city_2018['Parent Section'].nunique()
# Out:
# 15

# %%
city_2018['Parent Section'].unique()
# Out:
# array(['Water', 'Climate Hazards', 'Emissions Reduction: City-wide',
#        'Strategy', 'City Wide Emissions',
#        'Governance and Data Management', 'Hazards and Adaptation',
#        'Energy Data', 'Introduction', nan, 'Opportunities', 'Adaptation',
#        'Local Government Emissions',
#        'Emissions Reduction: Local Government', 'GHG Emissions Data',
#        'Local Government Operations GHG Emissions Data'], dtype=object)

# %%
city_2018.groupby(['Question Number']).agg('Response Answer').unique()
# Out:
# Question Number
# 0.1                  [City / Municipality, Lorena é um município br...
# 0.2                                                              [nan]
# 0.3                  [Henriette Reker, 2019, Ron Christie, 2018, 20...
# 0.4                  [USD US Dollar, AUD Australian Dollar, DKK Dan...
# 0.5                  [2018-12-31, 2510737944000, nan, 2018-01-01, 2...
#                                            ...
# 9.2a                 [2016, Other: All energy consumed(in TOE), The...
# 9.2b                 [Target is under development / consideration, ...
# 9.3                           [No, In progress, nan, Yes, Do not know]
# 9.3a                 [In accordance with the relevant provisions of...
# Response Language    [Spanish, English, Portuguese, French, Japanes...
# Name: Response Answer, Length: 169, dtype: object

# %%
city_2018[city_2018['Question Number']=='0.2']['Response Answer'].isnull().sum()
# Out:
# 370

# %%
introduction = city_2018['Question Number'].filter(regex='^0.')

# %%
introduction
# Out:
# Series([], Name: Question Number, dtype: object)

# %%
city_2018['Question Number'].str.startswith(('O.'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186829    False
# 186830    False
# 186831    False
# 186832    False
# 186833    False
# Name: Question Number, Length: 186834, dtype: bool

# %%
city_2018.dtypes
# Out:
# Questionnaire           object
# Year Reported to CDP     int64
# Account Number           int64
# Organization            object
# Country                 object
# CDP Region              object
# Parent Section          object
# Section                 object
# Question Number         object
# Question Name           object
# Column Number            int64
# Column Name             object
# Row Number               int64
# Row Name                object
# Response Answer         object
# Comments                object
# File Name               object
# Last update             object
# dtype: object

# %%
import re

# %%
introduction = ['0.1', '0.2', '0.3']

# %%
(city_2018['Question Number'].str.startswith(f'{0}.')).sum()
# Out:
# 11194

# %%
city_2018['Question Number'].shape
# Out:
# (186834,)

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{0}.')]['Question Number'].unique()
# Out:
# array(['0.5', '0.8', '0.6', '0.3', '0.1', '0.4', '0.7', '0.2'],
#       dtype=object)

# %%
introduction = city_2018.loc[city_2018['Question Number'].str.startswith(f'{0}.')]['Question Number'].unique()
governance = city_2018.loc[city_2018['Question Number'].str.startswith(f'{1}.')]['Question Number'].unique()
climate_hazards = city_2018.loc[city_2018['Question Number'].str.startswith(f'{2}.')]['Question Number'].unique()

# %%
adaptation = city_2018.loc[city_2018['Question Number'].str.startswith(f'{3}.')]['Question Number'].unique()
social_risks = city_2018.loc[city_2018['Question Number'].str.startswith(f'{4}.')]['Question Number'].unique()
opportunities = city_2018.loc[city_2018['Question Number'].str.startswith(f'{5}.')]['Question Number'].unique()
#boundary_scope = city_2018.loc[city_2018['Question Number'].str.startswith(f'{6}.')]['Question Number'].unique()

# %%
boundary = ['6.0', '6.1', '6.2', '6.3', '6.4']
energy_data = ['6.5', '6.6']
ghg_emissions = ['6.7','6.8','6.8a','6.8b','6.9']
ext_verification = ['6.10','6.10a', '6.10b']

# %%
city_wide_emissions = city_2018.loc[city_2018['Question Number'].str.startswith(f'{7}.')]['Question Number'].unique()
strategy_ghg = ['8.0','8.0a', '8.0b', '8.1']
strategy_emissions_reduction = ['8.2','8.2a','8.2b','8.2c','8.3', '8.3a', '8.3b','8.3c','8.3d','8.4']
energy = city_2018.loc[city_2018['Question Number'].str.startswith(f'{9}.')]['Question Number'].unique()

# %%
transport = city_2018.loc[city_2018['Question Number'].str.startswith(f'{11}.')]['Question Number'].unique()
water_supply = city_2018.loc[city_2018['Question Number'].str.startswith(f'{15}.')]['Question Number'].unique()
language = city_2018.loc[city_2018['Question Number'].str.startswith('Respo')]['Question Number'].unique()

# %%
waste_water= city_2018.loc[city_2018['Question Number'].str.startswith(f'{16}.')]['Question Number'].unique()
waste_strat= city_2018.loc[city_2018['Question Number'].str.startswith(f'{14}.')]['Question Number'].unique()
food_strat = city_2018.loc[city_2018['Question Number'].str.startswith(f'{13}.')]['Question Number'].unique()
urban_planning = city_2018.loc[city_2018['Question Number'].str.startswith(f'{12}.')]['Question Number'].unique()
building_strat = city_2018.loc[city_2018['Question Number'].str.startswith(f'{10}.')]['Question Number'].unique()

# %%
a = ['16.1', '2.2a', '8.4', '9.0', '7.13a', '7.11', '11.4', '1.2',
       '7.3a', '2.0c', '9.3', '6.5', '9.2a', '0.5', '2.4',
       'Response Language', '5.1a', '8.0b', '15.3a', '2.0b', '0.8', '6.6',
       '5.2', '2.0', '3.3', '10.9', '0.6', '0.3', '4.0a', '7.13', '7.0',
       '14.0', '7.2', '8.2b', '8.0a', '2.3', '3.1a', '0.1', '3.4', '6.1',
       '15.4', '5.1', '11.0', '15.3', '7.10', '7.5', '8.1', '8.2c', '3.6',
       '14.1', '7.7', '2.2', '1.4', '8.3', '1.4a', '6.8b', '5.5', '3.1',
       '3.9', '0.4', '3.7', '14.6', '6.8a', '6.0', '0.7', '8.3a', '7.8',
       '9.1', '9.2b', '1.3', '2.1a', '5.3', '7.12b', '3.8', '7.6a',
       '2.0a', '14.3', '6.9', '6.7', '6.10a', '1.1', '7.1', '8.3b',
       '9.3a', '5.4', '11.2', '10.7', '5.0', '3.2a', '3.0a', '5.8',
       '8.2a', '13.1', '9.2', '14.4', '15.0', '6.4', '7.4a', '11.5',
       '5.0a', '6.8', '15.3b', '14.5', '4.0', '10.8', '15.2', '0.2',
       '7.3', '1.8', '6.3', '8.3c', '7.12', '7.4b', '6.2', '5.7', '8.3d',
       '10.5', '7.12a', '1.0', '8.2', '10.0', '12.1', '6.10', '15.1',
       '7.6c', '2.1', '5.10', '3.0', '14.2', '3.1b', '3.5', '1.7', '12.0',
       '7.6d', '11.6', '16.3', '10.2', '1.10', '3.2', '6.10b', '10.6',
       '4.0b', '8.0', '1.5', '16.2', '7.10a', '11.3', '10.3', '5.9',
       '16.0', '7.6b', '7.9', '1.9', '10.1', '10.4', '16.3a', '7.4',
       '1.12', '9.0a', '5.6', '2.2b', '13.0', '11.1', '7.9a', '11.6a',
       '5.0b', '1.11', '1.6', '7.9b']

# %%
city_wide_emissions
# Out:
# array(['7.13a', '7.11', '7.3a', '7.13', '7.0', '7.2', '7.10', '7.5',
#        '7.7', '7.8', '7.12b', '7.6a', '7.1', '7.4a', '7.3', '7.12',
#        '7.4b', '7.12a', '7.6c', '7.6d', '7.10a', '7.6b', '7.9', '7.4',
#        '7.9a', '7.9b'], dtype=object)

# %%
list_sectors = ['introduction','governance','climate_hazards','adaptation','social_risks','opportunities','boundary','energy_data',
               'ghg_emissions','ext_verification','city_wide_emissions','strategy_ghg','strategy_emissions_reduction','energy',
               'transport', 'water_supply', 'language', 'waste_water', 'waste_strat', 'food_strat', 'urban_planning', 'building_strat']

# %%
list_sect = [introduction, governance , climate_hazards,adaptation,social_risks,opportunities,boundary,energy_data,
               ghg_emissions,ext_verification,city_wide_emissions,strategy_ghg,strategy_emissions_reduction,energy,
               transport, water_supply, language, waste_water, waste_strat, food_strat, urban_planning, building_strat]

# %%
w=0
z = []
for i in range(len(list_sect)):
    w = w+ len(list_sect[i])
    for j in range(len(list_sect[i])):
        z.append(list_sect[i][j])

# %%
for i in range(len(a)):
    if a[i] in z:
        print('ok')
    else:
        print(a[i])
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok

# %%
for i in range(len(z)):
    for y in range(len(a)):
        if a[y] in z[i]
# Out:
# [array(['0.5', '0.8', '0.6', '0.3', '0.1', '0.4', '0.7', '0.2'],
#        dtype=object),
#  array(['1.2', '1.4', '1.4a', '1.3', '1.1', '1.8', '1.0', '1.7', '1.10',
#         '1.5', '1.9', '1.12', '1.11', '1.6'], dtype=object),
#  array(['2.2a', '2.0c', '2.4', '2.0b', '2.0', '2.3', '2.2', '2.1a', '2.0a',
#         '2.1', '2.2b'], dtype=object),
#  array(['3.3', '3.1a', '3.4', '3.6', '3.1', '3.9', '3.7', '3.8', '3.2a',
#         '3.0a', '3.0', '3.1b', '3.5', '3.2'], dtype=object),
#  array(['4.0a', '4.0', '4.0b'], dtype=object),
#  array(['5.1a', '5.2', '5.1', '5.5', '5.3', '5.4', '5.0', '5.8', '5.0a',
#         '5.7', '5.10', '5.9', '5.6', '5.0b'], dtype=object),
#  ['6.0', '6.1', '6.2', '6.3', '6.4'],
#  ['6.5', '6.6'],
#  ['6.7', '6.8', '6.8a', '6.8b', '6.9'],
#  ['6.10', '6.10a', '6.10b'],
#  array(['7.13a', '7.11', '7.3a', '7.13', '7.0', '7.2', '7.10', '7.5',
#         '7.7', '7.8', '7.12b', '7.6a', '7.1', '7.4a', '7.3', '7.12',
# ...

# %% [markdown]
# city_2018['New Section']=city_2018['Question Number'].apply(lambda x:'introduction' if x in introduction else 'NaN')

# %% [markdown]
# for i in range(0,len(list_sectors)-1):
#     city_2018['New Section']=city_2018['Question Number'].apply(lambda x: f'{list_sectors[i]}' if x in list_sect[i] else pass)

# %%
city_2018.shape[0]

# %%
new_section_list = []
for y in range(city_2018.shape[0]):
    for i in range(0,len(list_sectors)):
        if city_2018['Question Number'][y] in list_sect[i]:
            new_section_list.append(f'{list_sectors[i]}')

# %%
city_2018['SectionN'] = new_section_list

# %%
city_2018
# Out:
#           Questionnaire  Year Reported to CDP  Account Number  \
# 0       CDP Cities 2018                  2018            3203
# 1       CDP Cities 2018                  2018           50555
# 2       CDP Cities 2018                  2018           50392
# 3       CDP Cities 2018                  2018           36522
# 4       CDP Cities 2018                  2018           35873
# ...                 ...                   ...             ...
# 186829  CDP Cities 2018                  2018           74594
# 186830  CDP Cities 2018                  2018           60602
# 186831  CDP Cities 2018                  2018           49334
# 186832  CDP Cities 2018                  2018           31108
# 186833  CDP Cities 2018                  2018           35858
#
#                     Organization                   Country     CDP Region  \
# 0                City of Chicago  United States of America  North America
# ...

# %%
city_2018

# %%
import numpy as np

# %%
w=0
for i in np.unique(new_section_list):
    print(i, new_section_list.count(i))
    w += new_section_list.count(i)
print(w)
# Out:
# adaptation 16974
# boundary 2282
# city_wide_emissions 12394
# climate_hazards 33805
# energy 11335
# energy_data 6224
# ext_verification 704
# ghg_emissions 2640
# governance 6790
# introduction 11194
# opportunities 12454
# social_risks 3435
# strategy_emissions_reduction 17195
# strategy_ghg 11396
# transport 20124
# 168946

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{6}.')]['Question Name'].nunique()
# Out:
# 15

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{12}.{1}')]['Response Answer'].value_counts(normalize=True, dropna=False) * 100
# Out:
# NaN     51.428571
# 100     15.714286
# 90       4.285714
# 89       2.857143
# 92       2.857143
# 99       2.857143
# 20       2.857143
# 75       2.857143
# 80       1.428571
# 96.7     1.428571
# 96       1.428571
# 68       1.428571
# 72       1.428571
# 95       1.428571
# 83       1.428571
# 94       1.428571
# 45       1.428571
# 77       1.428571
# Name: Response Answer, dtype: float64

# %%
city_2018.loc[city_2018['Question Number']==f'{14}.{6}a']['Response Answer'].value_counts(normalize=True, dropna=False) * 100
# Out:
# Series([], Name: Response Answer, dtype: float64)

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{14}.{6}')]['Question Name'].unique()
# Out:
# array(['Please provide details of your city’s landfill gas:'],
#       dtype=object)

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{14}.{6}')]
# Out:
#           Questionnaire  Year Reported to CDP  Account Number  \
# 143     CDP Cities 2018                  2018           54291
# 148     CDP Cities 2018                  2018           14874
# 184     CDP Cities 2018                  2018           35904
# 670     CDP Cities 2018                  2018            1184
# 4118    CDP Cities 2018                  2018           31150
# ...                 ...                   ...             ...
# 183402  CDP Cities 2018                  2018           14088
# 184080  CDP Cities 2018                  2018           16581
# 184318  CDP Cities 2018                  2018           31154
# 185262  CDP Cities 2018                  2018           35873
# 185796  CDP Cities 2018                  2018           31009
#
#                                Organization                   Country  \
# 143            Chengdu Municipal Government                     China
# 148                    City of Portland, OR  United States of America
# ...

# %%
city_2018.loc[city_2018['Question Number'].str.startswith(f'{11}.{1}')]['Question Name'].unique()
# Out:
# array(['What is the total distance travelled by all transport modes annually in your city (kms)?'],
#       dtype=object)

# %%
city_2018.loc[city_2018['Question Name'].str.startswith('Are you processing')]
# Out:
#           Questionnaire  Year Reported to CDP  Account Number  \
# 3101    CDP Cities 2018                  2018           31175
# 5197    CDP Cities 2018                  2018           35858
# 15694   CDP Cities 2018                  2018           31185
# 21505   CDP Cities 2018                  2018           35268
# 23365   CDP Cities 2018                  2018           31176
# 24643   CDP Cities 2018                  2018           31117
# 26724   CDP Cities 2018                  2018           35885
# 31440   CDP Cities 2018                  2018            3203
# 40266   CDP Cities 2018                  2018           31149
# 43130   CDP Cities 2018                  2018           31180
# 46033   CDP Cities 2018                  2018           31181
# 62110   CDP Cities 2018                  2018           31182
# 69180   CDP Cities 2018                  2018           54337
# 70597   CDP Cities 2018                  2018           31187
# ...

# %%
city_2018.loc[city_2018['Question Number'].str.startswith('Respo')].shape
# Out:
# (488, 18)

# %%
city_2018.loc[city_2018['Question Number'].str.startswith('Respo')].shape
# Out:
# (488, 18)

# %%
len(city_2018['Country'].unique())
# Out:
# 80
